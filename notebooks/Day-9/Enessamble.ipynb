# %%
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 9
#       7 from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor
#       8 from sklearn.linear_model import Ridge, ElasticNet, HuberRegressor
# ----> 9 from lightgbm import LGBMRegressor, early_stopping, log_evaluation
#      10 from scipy.stats import skew, kurtosis
#      11 from sklearn.metrics import mean_absolute_percentage_error
#
# File ~/LocalStorage/Developer/ShellAi/.venv/lib/python3.12/site-packages/lightgbm/__init__.py:11
#       7 from pathlib import Path
#       9 # .basic is intentionally loaded as early as possible, to dlopen() lib_lightgbm.{dll,dylib,so}
#      10 # and its dependencies as early as possible
# ---> 11 from .basic import Booster, Dataset, Sequence, register_logger
# ...
